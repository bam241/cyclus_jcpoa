# %%
import sys 
import os
sys.path.append(os.path.abspath("/Users/mouginot/work/helpmetric"))
import cymetrichelper as cyh
import pandahelper as pdh


import cymetric as cym
import pandas as pd
import matplotlib.pyplot as plt
from cymetric import graphs as cgr
from cymetric import timeseries as tm

# %matplotlib inline
# Out:
# /opt/local/Library/Frameworks/Python.framework/Versions/3.5/lib/python3.5/importlib/_bootstrap.py:222: QAWarning: pyne.data is not yet QA compliant.
#   return f(*args, **kwds)
# /opt/local/Library/Frameworks/Python.framework/Versions/3.5/lib/python3.5/importlib/_bootstrap.py:222: QAWarning: pyne.material is not yet QA compliant.
#   return f(*args, **kwds)
# /opt/local/Library/Frameworks/Python.framework/Versions/3.5/lib/python3.5/importlib/_bootstrap.py:222: QAWarning: pyne.enrichment is not yet QA compliant.
#   return f(*args, **kwds)

# %%
cyh.MakeFlowGraph("cascade_case_3.sqlite")

# %%
file = "cascade_case_2.sqlite"
receivers = [['cascade_0'], 
             ['cascade_1'], 
             ['cascade_2'], 
             ['cascade_3'], 
             ['cascade_4'], 
             ['cascade_5']]
sender = [['storage_nat'], 
          ['storage_0'], 
          ['storage_1'], 
          ['storage_2'], 
          ['storage_3'], 
          ['storage_4']]
nucs1 = ['238U']
nucs2 = ['235U']
uma_238u = 238050786.996e-6
uma_235u = 235043928.190e-6

c_names = ['C0',
           'C1',
           'C2',
           'C3',
           'C4',
           'C5']
labels = ['Cascade0',
          'Cascade0rec',
          'Cascade1',
          'Cascade2',
          'Cascade3',
          'Cascade4',
          'Cascade5']

feed_case_2 = [] 
plt_feed_case_2 = []
for i in range(6):
    df_ = cyh.TransFrac(file, receivers[i], sender[i], nucs1, nucs2,uma_238u, uma_235u)
    df_ = pdh.RenameTS(pdh.RemoveNan(df_), "Time", c_names[i])
    feed_case_2.append(df_)
    plt_feed_case_2.append( (df_, c_names[i]) )
    
pdh.MakePlot(plt_feed_case_2, "Time", "Feed Enrichment" )

# %%
file = "cascade_case_3.sqlite"

feed_case_3 = [] 
plt_feed_case_3 = []
for i in range(6):
    df_ = cyh.TransFrac(file, receivers[i], sender[i], nucs1, nucs2,uma_238u, uma_235u)
    df_ = pdh.RenameTS(pdh.RemoveNan(df_), "Time", c_names[i])
    feed_case3.append(df_)
    plt_feed_case_3.append( (df_, c_names[i]) )
    
pdh.MakePlot(plt_feed_case_3, "Time", "Feed Enrichment" )

# %%
file = "cascade_case_4.sqlite"

feed_case_4 = [] 
plt_feed_case_4 = []
for i in range(6):
    df_ = cyh.TransFrac(file, receivers[i], sender[i], nucs1, nucs2,uma_238u, uma_235u)
    df_ = pdh.RenameTS(pdh.RemoveNan(df_), "Time", c_names[i])
    feed_case_4.append(df_)
    plt_feed_case_4.append( (df_, c_names[i]) )
    
pdh.MakePlot(plt_feed_case_4, "Time", "Feed Enrichment" )

# %%
file = "cascade_case_1.sqlite"

feed_case_1 = [] 
plt_feed_case_1 = []
for i in range(6):
    df_ = cyh.TransFrac(file, receivers[i], sender[i], nucs1, nucs2,uma_238u, uma_235u)
    df_ = pdh.RenameTS(pdh.RemoveNan(df_), "Time", c_names[i])
    feed_case_1.append(df_)
    plt_feed_case_1.append( (df_, c_names[i]) )
    
pdh.MakePlot(plt_feed_case_1, "Time", "Feed Enrichment" )
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-18-9abd46b98dae> in <module>()
#       4 plt_feed_case_1 = []
#       5 for i in range(6):
# ----> 6     df_ = cyh.TransFrac(file, receivers[i], sender[i], nucs1, nucs2,uma_238u, uma_235u)
#       7     df_ = pdh.RenameTS(pdh.RemoveNan(df_), "Time", c_names[i])
#       8     feed_case_1.append(df_)
#
# ~/work/helpmetric/cymetrichelper.py in TransFrac(file, rec, send, nucs1, nucs2, factor1, factor2)
#      22     df1 = tm.transactions(ev, receivers=rec, senders=send, nucs=nucs1)
#      23     df2 = tm.transactions(ev, receivers=rec, senders=send, nucs=nucs2)
# ---> 24     df_r = df2
#      25     df_r[df_r.columns[1]] = (df2[df2.columns[1]] / factor2) / \
#      26         (df1[df1.columns[1]] / factor1 + df2[df2.columns[1]] / factor2)
#
# ...

# %%
file = "cascade_case_4.sqlite"
feed_0 = get_frac_transaction(file, rec=['cascade_0'], send=['nu_src'])
feed_0b = get_frac_transaction(file, rec=['cascade_0'], send=['storage_nat'])
feed_1 = get_frac_transaction(file, rec=['cascade_1'], send=['storage_0'])
feed_2 = get_frac_transaction(file, rec=['cascade_2'], send=['storage_1'])
feed_3 = get_frac_transaction(file, rec=['cascade_3'], send=['storage_2'])
feed_4 = get_frac_transaction(file, rec=['cascade_4'], send=['storage_3'])
feed_5 = get_frac_transaction(file, rec=['cascade_5'], send=['storage_4'])
plt_str = []
plt_str.append( (format_df(feed_0, "Time", "Cascade 0"), 'Cascade 0' ))
plt_str.append( (format_df(feed_0b, "Time", "Cascade 0 recycled"), 'Cascade 0 recycled' ))
plt_str.append( (format_df(feed_1, "Time", "Cascade 1"), 'Cascade 1' ))
plt_str.append( (format_df(feed_2, "Time", "Cascade 2"), 'Cascade 2' ))
plt_str.append( (format_df(feed_3, "Time", "Cascade 3"), 'Cascade 3' ))
plt_str.append( (format_df(feed_4, "Time", "Cascade 4"), 'Cascade 4' ))
plt_str.append( (format_df(feed_5, "Time", "Cascade 5"), 'Cascade 5' ))

make_plot(plt_str, "Time", "Feed Enrichment" )

# %%
file = "cascade_case_3.sqlite"

tails_0 = get_frac_transaction(file, send=['cascade_0'], rec=['waste'])
tails_1 = get_frac_transaction(file, send=['cascade_1'], rec=['storage_nat'])
tails_2 = get_frac_transaction(file, send=['cascade_2'], rec=['storage_0'])
plt_str = []
plt_str.append( (format_df(tails_0, "Time", "Cascade 0"), 'Cascade 0' ))
plt_str.append( (format_df(tails_1, "Time", "Cascade 1"), 'Cascade 1' ))
plt_str.append( (format_df(tails_2, "Time", "Cascade 2"), 'Cascade 2' ))
make_plot(plt_str, "Time", "Tails Enrichment" )

# %%
#STG-0
get_frac_transaction("cyclus_stg_0.sqlite", send=['cascade_0'], rec=['waste']).at[20,'Mass']
# Out:
# -----------------------------------------------------------------
# AttributeError                  Traceback (most recent call last)
# <ipython-input-12-df9db970bc70> in <module>()
#       1 #STG-0
# ----> 2 get_frac_transaction("cyclus_stg_0.sqlite", send=['cascade_0'], rec=['waste']).at[20,'Mass']
#
# <ipython-input-2-cc4cb13dc056> in get_frac_transaction(file, rec, send)
#      35     db = cym.dbopen(file)
#      36     ev = cym.Evaluator(db=db, write=False)
# ---> 37     df1_u8 = tm.transactions(ev, receivers=rec, senders=send, nucs=['238U'])
#      38     df1_u5 = tm.transactions(ev, receivers=rec, senders=send, nucs=['235U'])
#      39     df_r = df1_u5
#
# ~/.local/lib/python3.5/site-packages/cymetric/timeseries.py in transactions(evaler, senders, receivers, commodities, nucs)
#      34
#      35     df = filters.transactions_nuc(
# ---> 36         evaler, senders, receivers, commodities, nucs)
#      37
# ...

# %%
#STG-1
get_frac_transaction("cyclus_stg_1.sqlite", send=['cascade_0'], rec=['waste']).at[20,'Mass']

# %%
#STG-2
get_frac_transaction("cyclus_stg_2.sqlite", send=['cascade_0'], rec=['waste']).at[20,'Mass']

# %%
#STG-3
get_frac_transaction("cyclus_stg_3.sqlite", send=['cascade_0'], rec=['waste']).at[20,'Mass']

# %%
#STG-4
get_frac_transaction("cyclus_stg_4.sqlite", send=['cascade_0'], rec=['waste']).at[20,'Mass']

# %%
#STG-5
get_frac_transaction("cyclus_stg_5.sqlite", send=['cascade_0'], rec=['waste']).at[20,'Mass']
# Out:
# 0.81740963123041444

# %%
frac_atom_to_mass(0.026697979287772927)
# Out:
# 0.026360752702064585

# %%
feed_0b
# Out:
#      Time      Mass
# 0       0  0.000000
# 1       1  0.000000
# 2       2  0.007100
# 3       3  0.000000
# 4       4  0.007100
# 5       5  0.007100
# 6       6  0.007100
# 7       7  0.007100
# 8       8  0.007100
# 9       9  0.007102
# 10     10  0.007102
# 11     11  0.007102
# 12     12  0.007102
# 13     13  0.007102
# 14     14  0.007104
# 15     15  0.007104
# 16     16  0.007105
# 17     17  0.007105
# 18     18  0.007105
# 19     19  0.007106
# 20     20  0.007106
# 21     21  0.007107
# 22     22  0.007107
# 23     23  0.007107
# 24     24  0.007107
# 25     25  0.007107
# 26     26  0.007108
# 27     27  0.007108
# 28     28  0.007108
# 29     29  0.007108
# ..    ...       ...
# 170   170  0.000000
# 171   171  0.000000
# 172   172  0.000000
# 173   173  0.000000
# 174   174  0.000000
# 175   175  0.000000
# 176   176  0.000000
# 177   177  0.000000
# 178   178  0.000000
# 179   179  0.000000
# 180   180  0.000000
# 181   181  0.000000
# 182   182  0.000000
# ...
