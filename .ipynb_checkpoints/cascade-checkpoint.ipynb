# %%
import cymetric as cym
import pandas as pd
import matplotlib.pyplot as plt
import sys
from cymetric import graphs as cgr
from cymetric import timeseries as tm

# %matplotlib inline
# Out:
# /opt/local/Library/Frameworks/Python.framework/Versions/3.5/lib/python3.5/importlib/_bootstrap.py:222: QAWarning: pyne.data is not yet QA compliant.
#   return f(*args, **kwds)
# /opt/local/Library/Frameworks/Python.framework/Versions/3.5/lib/python3.5/importlib/_bootstrap.py:222: QAWarning: pyne.material is not yet QA compliant.
#   return f(*args, **kwds)
# /opt/local/Library/Frameworks/Python.framework/Versions/3.5/lib/python3.5/importlib/_bootstrap.py:222: QAWarning: pyne.enrichment is not yet QA compliant.
#   return f(*args, **kwds)

# %%
def fracmass_to_frac_atom(mass):
    uma_235 = 235043928.190e-6
    uma_238 = 238050786.996e-6
    return mass * uma_238 / uma_235

def get_frac(file, facility):
    uma_235 = 235043928.190e-6
    uma_238 = 238050786.996e-6
    db = cym.dbopen(file)
    ev = cym.Evaluator(db=db, write=False)
    df1_u8 = tm.inventories(ev, facilities=facility, nucs=['238U'])
    df1_u5 = tm.inventories(ev, facilities=facility, nucs=['235U'])
    df_r = df1_u5
    df_r[df_r.columns[1]] = (df1_u5[df1_u5.columns[1]]/uma_235)/(df1_u8[df1_u8.columns[1]]/uma_238 + df1_u5[df1_u5.columns[1]]/uma_235)
    return df_r

def get_frac_transaction(file, receivers=[''], senders=['']):
    uma_235 = 235043928.190e-6
    uma_238 = 238050786.996e-6
    db = cym.dbopen(file)
    ev = cym.Evaluator(db=db, write=False)
    df1_u8 = tm.transactions(ev, receivers=receivers, senders=senders, nucs=['238U'])
    df1_u5 = tm.transactions(ev, receivers=receivers, senders=senders, nucs=['235U'])
    df_r = df1_u5
    df_r[df_r.columns[1]] = (df1_u5[df1_u5.columns[1]]/uma_235)/(df1_u8[df1_u8.columns[1]]/uma_238 + df1_u5[df1_u5.columns[1]]/uma_235)
    return df_r

def format_df(df, x_label, y_label):
    df.fillna(0, inplace=True)
    return pd.DataFrame({x_label: df[df.columns[0]], y_label: df[df.columns[1]]})

def make_plot(dfs, x_name, y_name, figsize = (20,12), mk = 'x', mk_z=14, linestyle=' ', mfc='none'):
    e1x = dfs[0].plot(x=x_name, y=y_name, 
                      marker=mk, markersize=mk_z, linestyle=linestyle, 
                      mfc=mfc, figsize=figsize)
    for df in dfs[1:]:
        df.plot(x=x_name, y=y_name, 
                      marker=mk, markersize=mk_z, linestyle=linestyle, 
                      mfc=mfc, figsize=figsize, ax=e1x)

    plt.xlabel(x_name)
    plt.ylabel(y_name)
    #plt.savefig('trans.png', dpi=326)
    plt.legend()

# %%
db_ = cym.dbopen("cyclus.sqlite")
ev_ = cym.Evaluator(db=db_, write=False)
file = "cyclus.sqlite"

# %%
flow_graph = cgr.flow_graph(ev_)
flow_graph

# %%
in_str_0 = get_frac_transaction(file, receivers=['storage_0'], senders=['cascade_0'])
in_str_1 = get_frac_transaction(file, receivers=['storage_1'], senders=['cascade_1'])
in_str_2 = get_frac_transaction(file, receivers=['storage_2'], senders=['cascade_2'])
in_str_3 = get_frac_transaction(file, receivers=['storage_3'], senders=['cascade_3'])
in_str_4 = get_frac_transaction(file, receivers=['storage_4'], senders=['cascade_4'])
in_str_5 = get_frac_transaction(file, receivers=['storage_5'], senders=['cascade_5'])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-67-1b3065145ecb> in <module>()
# ----> 1 in_str_0 = get_frac_transaction(file, receivers=['storage_0'], senders=['cascade_1'])
#       2 in_str_1 = get_frac_transaction(file, receivers=['storage_1'], senders=['cascade_1'])
#       3 in_str_2 = get_frac_transaction(file, receivers=['storage_2'], senders=['cascade_2'])
#       4 in_str_3 = get_frac_transaction(file, receivers=['storage_3'], senders=['cascade_3'])
#       5 in_str_4 = get_frac_transaction(file, receivers=['storage_4'], senders=['cascade_4'])
#
# <ipython-input-63-7270530bb0a8> in get_frac_transaction(file, receivers, senders)
#      20     db = cym.dbopen(file)
#      21     ev = cym.Evaluator(db=db, write=False)
# ---> 22     df1_u8 = tm.transactions(ev, receivers=receivers, senders=senders, nucs=['238U'])
#      23     df1_u5 = tm.transactions(ev, receivers=receivers, senders=senders, nucs=['235U'])
#      24     df_r = df1_u5
#
# ~/.local/lib/python3.5/site-packages/cymetric/timeseries.py in transactions(evaler, senders, receivers, commodities, nucs)
#      34
#      35     df = filters.transactions_nuc(
# ---> 36         evaler, senders, receivers, commodities, nucs)
#      37
#      38     group_end = ['ReceiverPrototype', 'SenderPrototype', 'Time']
#
# ~/.local/lib/python3.5/site-packages/cymetric/filters.py in transactions_nuc(evaler, senders, receivers, commodities, nucs)
#     101     base_col = ['SimId', 'ResourceId']
#     102     added_col = base_col + ['NucId', 'Mass']
# --> 103     df = merge(df, base_col, compo, added_col)
#     104
#     105     return df
#
# ~/.local/lib/python3.5/site-packages/cymetric/tools.py in merge(df, base_col, add_df, add_col)
#     129     add_col: columns to be added
#     130     """
# --> 131     df = pd.merge(add_df[add_col], df, on=base_col)
#     132     df.drop(base_col[1], 1)
#     133     return df
#
# /opt/local/Library/Frameworks/Python.framework/Versions/3.5/lib/python3.5/site-packages/pandas/core/reshape/merge.py in merge(left, right, how, on, left_on, right_on, left_index, right_index, sort, suffixes, copy, indicator)
#      51                          right_on=right_on, left_index=left_index,
#      52                          right_index=right_index, sort=sort, suffixes=suffixes,
# ---> 53                          copy=copy, indicator=indicator)
#      54     return op.get_result()
#      55
#
# /opt/local/Library/Frameworks/Python.framework/Versions/3.5/lib/python3.5/site-packages/pandas/core/reshape/merge.py in __init__(self, left, right, how, on, left_on, right_on, axis, left_index, right_index, sort, suffixes, copy, indicator)
#     533             raise ValueError(
#     534                 'can not merge DataFrame with instance of '
# --> 535                 'type {0}'.format(type(right)))
#     536
#     537         if not is_bool(left_index):
#
# ValueError: can not merge DataFrame with instance of type <class 'NoneType'>

# %%
plt_str = []
plt_str.append(format_df(in_str_0, "Time", "Fraction"))
plt_str.append(format_df(in_str_1, "Time", "Fraction"))
plt_str.append(format_df(in_str_2, "Time", "Fraction"))
plt_str.append(format_df(in_str_3, "Time", "Fraction"))
plt_str.append(format_df(in_str_4, "Time", "Fraction"))
plt_str.append(format_df(in_str_5, "Time", "Fraction"))
make_plot(plt_str, "Time", "Fraction" )

# %%
in_str_3
# Out:
#      Time      Mass
# 0       0  0.000000
# 1       1  0.000000
# 2       2  0.000000
# 3       3  0.000000
# 4       4  0.000000
# 5       5  0.000000
# 6       6  0.000000
# 7       7  0.000000
# 8       8  0.594024
# 9       9  0.000000
# 10     10  0.594024
# 11     11  0.000000
# 12     12  0.599551
# 13     13  0.777606
# 14     14  0.599551
# 15     15  0.777606
# 16     16  0.600797
# 17     17  0.782140
# 18     18  0.728068
# 19     19  0.782140
# 20     20  0.728196
# 21     21  0.783156
# 22     22  0.734959
# 23     23  0.865432
# 24     24  0.734988
# 25     25  0.865521
# 26     26  0.736778
# 27     27  0.870055
# 28     28  0.799323
# 29     29  0.870075
# ..    ...       ...
# 90     90  0.907817
# 91     91  0.962493
# 92     92  0.908813
# 93     93  0.962896
# 94     94  0.909355
# 95     95  0.963301
# 96     96  0.910243
# 97     97  0.963750
# 98     98  0.910810
# 99     99  0.963996
# 100   100  0.911481
# 101   101  0.964396
# 102   102  0.912094
# 103   103  0.964650
# 104   104  0.912549
# 105   105  0.964952
# 106   106  0.913130
# 107   107  0.965226
# 108   108  0.913528
# 109   109  0.965431
# 110   110  0.914007
# 111   111  0.965691
# 112   112  0.914403
# 113   113  0.965868
# 114   114  0.914759
# 115   115  0.966082
# 116   116  0.915139
# 117   117  0.966258
# 118   118  0.915430
# 119   119  0.966417
#
# [120 rows x 2 columns]
