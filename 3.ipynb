# %%
import sys 
import os
sys.path.append(os.path.abspath("/Users/mouginot/work/helpmetric"))
import cymetrichelper as cyh
import pandahelper as pdh


import cymetric as cym
import pandas as pd

import numpy as np

import matplotlib.pyplot as plt
from cymetric import graphs as cgr
from cymetric import timeseries as tm

# %matplotlib inline
# Out:
# /opt/local/Library/Frameworks/Python.framework/Versions/3.5/lib/python3.5/importlib/_bootstrap.py:222: QAWarning: pyne.data is not yet QA compliant.
#   return f(*args, **kwds)
# /opt/local/Library/Frameworks/Python.framework/Versions/3.5/lib/python3.5/importlib/_bootstrap.py:222: QAWarning: pyne.material is not yet QA compliant.
#   return f(*args, **kwds)
# /opt/local/Library/Frameworks/Python.framework/Versions/3.5/lib/python3.5/importlib/_bootstrap.py:222: QAWarning: pyne.enrichment is not yet QA compliant.
#   return f(*args, **kwds)

# %%
flow = cyh.MakeFlowGraph("case_2_/cascade_case_2_no_rec_raw_S2.sqlite", label='')
flow.body.pop(0)
flow

# %%
import re

flow.body
for i in range(len(flow.body)):
    flow.body[i] = re.sub('(storage_2)', 'storage_HEU', flow.body[i])
    #flow.body[i] = re.sub('(storage)', 'str', flow.body[i])
    #flow.body[i] = re.sub('(cascade)', 'cscd', flow.body[i])

flow.view(filename='flow_case_2_recy')
# Out:
# 'flow_case_2_recy.pdf'

# %%
file = "case_3_/cascade_case_3_raw_S4.sqlite"
sender = [['cascade_0'], 
             ['cascade_1'], 
             ['cascade_2'], 
             ['cascade_3'], 
             ['cascade_4'], 
             ['cascade_5']]
receivers = [['storage_0'], 
          ['storage_1'], 
          ['storage_2'], 
          ['storage_3'], 
          ['storage_4'],
            ['storage_5']]
nucs1 = ['238U']
nucs2 = ['235U']
uma_238u = 238050786.996e-6
uma_235u = 235043928.190e-6

c_names = ['Level 0',
           'Level 1',
           'Level 2',
           'Level 3',
           'Level 4',
           'Level 5']
labels = ['Cascade0',
          'Cascade0rec',
          'Cascade1',
          'Cascade2',
          'Cascade3',
          'Cascade4',
          'Cascade5']

# %%
file = "case_3_/cascade_case_3_raw_S3.sqlite"


feed_case_2 = [] 
plt_feed_case_2 = []
for i in range(4):
    df_ = cyh.TransFrac(file, receivers[i], sender[i], nucs1, nucs2,uma_238u, uma_235u)
    df_ = pdh.RenameTS(pdh.RemoveNan(df_), "Time [y]", c_names[i])
    df_['Time [y]'] *= 1/12.
    feed_case_2.append(df_)
    plt_feed_case_2.append( (df_, c_names[i]) )
    
pdh.MakePlot(plt_feed_case_2, "Time [y]", "Product Enrichment [N.A]" , loc='center right')
plt.axhline(y=0.9)
plt.savefig("assay_case_2_rec.png")

# %%
file = "case_3_/cascade_case_3_raw_S3.sqlite"


feed_case_2 = [] 
plt_feed_case_2 = []
for i in range(4):
    df_ = cyh.TransFrac(file, receivers[i], sender[i], nucs1, nucs2,uma_238u, uma_235u)
    df_ = pdh.RenameTS(pdh.RemoveNan(df_), "Time [y]", c_names[i])
    df_['Time [y]'] *= 1/12.
    feed_case_2.append(df_)
    plt_feed_case_2.append( (df_, c_names[i]) )
    
pdh.MakePlot(plt_feed_case_2, "Time [y]", "Product Enrichment [N.A]" , loc='center right')
plt.axhline(y=0.9)
plt.savefig("assay_case_2_rec.png")

# %%
plt_feed_case_2[3]
# Out:
# (      Level 3   Time [y]
#  0    0.000000   0.000000
#  1    0.000000   0.083333
#  2    0.000000   0.166667
#  3    0.000000   0.250000
#  4    0.000000   0.333333
#  5    0.000000   0.416667
#  6    0.000000   0.500000
#  7    0.000000   0.583333
#  8    0.000000   0.666667
#  9    0.883365   0.750000
#  10   0.883365   0.833333
#  11   0.883365   0.916667
#  12   0.883365   1.000000
#  13   0.883365   1.083333
#  14   0.883365   1.166667
#  15   0.883365   1.250000
#  16   0.883365   1.333333
#  17   0.883365   1.416667
#  18   0.883365   1.500000
#  19   0.883365   1.583333
#  20   0.883365   1.666667
#  21   0.883365   1.750000
#  22   0.883365   1.833333
#  23   0.883365   1.916667
#  24   0.883365   2.000000
#  25   0.883365   2.083333
#  26   0.883365   2.166667
#  27   0.883365   2.250000
#  28   0.883365   2.333333
#  29   0.883365   2.416667
#  ..        ...        ...
#  150  0.883365  12.500000
#  151  0.883365  12.583333
#  152  0.883365  12.666667
#  153  0.883365  12.750000
#  154  0.883365  12.833333
#  155  0.883365  12.916667
#  156  0.883365  13.000000
#  157  0.883365  13.083333
#  158  0.883365  13.166667
#  159  0.883365  13.250000
#  160  0.883365  13.333333
#  161  0.883365  13.416667
#  162  0.883365  13.500000
#  163  0.883365  13.583333
#  164  0.883365  13.666667
#  165  0.883365  13.750000
#  166  0.883365  13.833333
#  167  0.883365  13.916667
#  168  0.883365  14.000000
#  169  0.883365  14.083333
#  170  0.883365  14.166667
#  171  0.883365  14.250000
#  172  0.883365  14.333333
#  173  0.883365  14.416667
#  174  0.883365  14.500000
#  175  0.883365  14.583333
#  176  0.883365  14.666667
#  177  0.883365  14.750000
#  178  0.883365  14.833333
#  179  0.883365  14.916667
#
#  [180 rows x 2 columns], 'Level 3')

# %%
file = "cascade_case_2_no_rec_24_4_1_1.sqlite"


feed_case_2 = [] 
plt_feed_case_2 = []
for i in range(4):
    df_ = cyh.TransFrac(file, receivers[i], sender[i], nucs1, nucs2,uma_238u, uma_235u)
    df_ = pdh.RenameTS(pdh.RemoveNan(df_), "Time", c_names[i])
    df_['Time'] *= 1/12.
    feed_case_2.append(df_)
    plt_feed_case_2.append( (df_, c_names[i]) )
    
pdh.MakePlot(plt_feed_case_2, "Time", "Feed Enrichment" )
plt.axhline(y=0.9)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-8-3d5383d7b5fb> in <module>()
#       5 plt_feed_case_2 = []
#       6 for i in range(4):
# ----> 7     df_ = cyh.TransFrac(file, receivers[i], sender[i], nucs1, nucs2,uma_238u, uma_235u)
#       8     df_ = pdh.RenameTS(pdh.RemoveNan(df_), "Time", c_names[i])
#       9     df_['Time'] *= 1/12.
#
# ~/work/helpmetric/cymetrichelper.py in TransFrac(file, rec, send, nucs1, nucs2, factor1, factor2)
#      20     db = cym.dbopen(file)
#      21     ev = cym.Evaluator(db=db, write=False)
# ---> 22     df1 = tm.transactions(ev, receivers=rec, senders=send, nucs=nucs1)
#      23     df2 = tm.transactions(ev, receivers=rec, senders=send, nucs=nucs2)
#      24     df_r = df2
#
# ~/.local/lib/python3.5/site-packages/cymetric/timeseries.py in transactions(evaler, senders, receivers, commodities, nucs)
#      34
#      35     df = filters.transactions_nuc(
# ---> 36         evaler, senders, receivers, commodities, nucs)
#      37
#      38     group_end = ['ReceiverPrototype', 'SenderPrototype', 'Time']
#
# ~/.local/lib/python3.5/site-packages/cymetric/filters.py in transactions_nuc(evaler, senders, receivers, commodities, nucs)
#      91     """
#      92
# ---> 93     compo = evaler.eval('Materials')
#      94
#      95     df = transactions(evaler, senders, receivers, commodities)
#
# ~/.local/lib/python3.5/site-packages/cymetric/evaluator.py in eval(self, metric, conds)
#      58             frame = self.eval(dep, conds=conds)
#      59             frames.append(frame)
# ---> 60         raw = m(frames=frames, conds=conds, known_tables=self.known_tables)
#      61         if raw is None:
#      62             return raw
#
# ~/.local/lib/python3.5/site-packages/cymetric/metrics.py in __call__(self, frames, conds, known_tables, *args, **kwargs)
#      74             if self.name in known_tables:
#      75                 return self.db.query(self.name, conds=conds)
# ---> 76             return f(*frames)
#      77
#      78     Cls.__name__ = str(name)
#
# ~/.local/lib/python3.5/site-packages/cymetric/metrics.py in materials(rsrcs, comps)
#     113     ResourceId, ObjId, TimeCreated, and NucId.
#     114     """
# --> 115     x = pd.merge(rsrcs, comps, on=['SimId', 'QualId'], how='inner')
#     116     x = x.set_index(['SimId', 'QualId', 'ResourceId', 'ObjId','TimeCreated',
#     117                      'NucId', 'Units'])
#
# /opt/local/Library/Frameworks/Python.framework/Versions/3.5/lib/python3.5/site-packages/pandas/core/reshape/merge.py in merge(left, right, how, on, left_on, right_on, left_index, right_index, sort, suffixes, copy, indicator)
#      51                          right_on=right_on, left_index=left_index,
#      52                          right_index=right_index, sort=sort, suffixes=suffixes,
# ---> 53                          copy=copy, indicator=indicator)
#      54     return op.get_result()
#      55
#
# /opt/local/Library/Frameworks/Python.framework/Versions/3.5/lib/python3.5/site-packages/pandas/core/reshape/merge.py in __init__(self, left, right, how, on, left_on, right_on, axis, left_index, right_index, sort, suffixes, copy, indicator)
#     529             raise ValueError(
#     530                 'can not merge DataFrame with instance of '
# --> 531                 'type {0}'.format(type(left)))
#     532         if not isinstance(right, DataFrame):
#     533             raise ValueError(
#
# ValueError: can not merge DataFrame with instance of type <class 'NoneType'>

# %%
files = ['cascade_case_2_no_rec_24_4_1_1.sqlite',
         'cascade_case_1.sqlite']
invs = ['storage_3',
        
        'storage']

c_names = ['24/4/1/1','REF']

LEU_qty_case_2_x = []
plt_LEU_qty_case_2_x = []

for i in range(2):
    db_ = cym.dbopen(files[i])
    ev_ = cym.Evaluator(db=db_, write=False)

    df_ = tm.inventories(ev_, [invs[i]])
    df_ = pdh.RenameTS(pdh.RemoveNan(df_), "Time", c_names[i])
    df_['Time'] *= 1/12.
    LEU_qty_case_2_x.append(df_)
    plt_LEU_qty_case_2_x.append( (LEU_qty_case_2_x[i], c_names[i]) )
    
pdh.MakePlot(plt_LEU_qty_case_2_x, "Time", "LEU Amount" )
plt.axhline(y=25)

x = np.arange(0, 16, 1);
#plt.plot(x, x*4.818481656138361*1*12, linewidth=4);

#plt.plot(x, x*4.306458967931736*1*12, linewidth=4);

#plt.plot(x, x*4.818481656138361*2*12, linewidth=4);
#plt.plot(x, x*4.818481656138361*3*12, linewidth=4);
#plt.plot(x, x*4.818481656138361*4*12, linewidth=4);
#plt.plot(x, x*4.818481656138361*5*12, linewidth=4);
